# %% [markdown]
# # PANDAS

# %%
import numpy as np
import pandas as pd

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\lenovo\desktop\PANDAS

# %%
l=[10,20,30,40,50]
print(l)
s1=pd.Series(l)
print(s1)
# Out:
# [10, 20, 30, 40, 50]
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1=[["Ram","Shyam","krishna"],
    [10,11,12],
    [98.5,67.2,28.6],
    ["noida","delhi","gurgaon"]]
print(s1)
# Out:
# [['Ram', 'Shyam', 'krishna'], [10, 11, 12], [98.5, 67.2, 28.6], ['noida', 'delhi', 'gurgaon']]

# %%
df=pd.DataFrame(s1)
df
# Out:
#        0      1        2
# 0    Ram  Shyam  krishna
# 1     10     11       12
# 2   98.5   67.2     28.6
# 3  noida  delhi  gurgaon

# %%
df.columns= ["students1","students2","students3"]
df
# Out:
#   students1 students2 students3
# 0       Ram     Shyam   krishna
# 1        10        11        12
# 2      98.5      67.2      28.6
# 3     noida     delhi   gurgaon

# %%
s1= [["ram","shyam","krishna"],
    [10,11,12],
     [98.5,67.2,28.6],
     ["noida","delhi","gurgaon"]]
print(s1)
df1=pd.DataFrame(s1,columns="A B C".split())
df1
# Out:
# [['ram', 'shyam', 'krishna'], [10, 11, 12], [98.5, 67.2, 28.6], ['noida', 'delhi', 'gurgaon']]
#        A      B        C
# 0    ram  shyam  krishna
# 1     10     11       12
# 2   98.5   67.2     28.6
# 3  noida  delhi  gurgaon

# %%
sd={"Name":["muskan","aryan","aakriti"],
   "Mob":[9835342,36344256,98725424]}
print(sd)
# Out:
# {'Name': ['muskan', 'aryan', 'aakriti'], 'Mob': [9835342, 36344256, 98725424]}

# %%
df2=pd.DataFrame(sd)
df2
# Out:
#       Name       Mob
# 0   muskan   9835342
# 1    aryan  36344256
# 2  aakriti  98725424

# %%
ab={"Name":["sam","pia","smiley"],
   "Age":[12,13,14]}
print(ab)
# Out:
# {'Name': ['sam', 'pia', 'smiley'], 'Age': [12, 13, 14]}

# %%
df = pd.DataFrame(ab)
df
# Out:
#      Name  Age
# 0     sam   12
# 1     pia   13
# 2  smiley   14

# %%
# random choice
# random.randint

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\lenovo\\desktop\\PANDAS'

# %%
#how to load data csv into pandas
# df=pd.read_csv("path of file")

# %%
df=pd.read_csv(r"C:\Users\lenovo\Downloads\SampleSuperstore.csv")
df                          #import csv file in pandas
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df=pd.read_excel(r"C:\Users\lenovo\Downloads\SampleSuperstore (Autosaved).xlsv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df=pd.read_excel(r"C:\Users\lenovo\Downloads\SampleSuperstore (Autosaved).xlsv")
#       2 df
#
# File ~\OneDrive\Attachments\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df=pd.read_excel(r"C:\Users\lenovo\Downloads\SampleSuperstore (Autosaved).xlsv",skiprows=500)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df=pd.read_excel(r"C:\Users\lenovo\Downloads\SampleSuperstore (Autosaved).xlsv",skiprows=500)
#       2 df
#
# File ~\OneDrive\Attachments\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
df=pd.read_csv(r"C:\Users\lenovo\Downloads\stock_data.csv")
df
# Out:
#    Unnamed: 0 Tickers    Eps  Revenue Price         People
# 0           0   GOOGL  27.82     87.0   845     Larry Page
# 1           1     WMT   4.61      NaN    65            NaN
# 2           2    MSFT    NaN     85.0    64     Bill Gates
# 3           3    RIL     NaN     50.0  1023  Mukesh Ambani
# 4           4    TATA   5.60      NaN  N.A.     Ratan Tata

# %%
df=pd.read_csv(r"C:\Users\lenovo\Downloads\stock_data.csv" , names = "A B C D E".split())
df
# Out:
#            A      B        C      D              E
# NaN  Tickers    Eps  Revenue  Price         People
# 0.0    GOOGL  27.82     87.0    845     Larry Page
# 1.0      WMT   4.61      NaN     65            NaN
# 2.0     MSFT    NaN     85.0     64     Bill Gates
# 3.0     RIL     NaN     50.0   1023  Mukesh Ambani
# 4.0     TATA    5.6      NaN   N.A.     Ratan Tata

# %%
df.head(2) #top 2 column
# Out:
#            A      B        C      D           E
# NaN  Tickers    Eps  Revenue  Price      People
# 0.0    GOOGL  27.82     87.0    845  Larry Page

# %%
df.tail(2)  #bottom 2 column
# Out:
#         A    B     C     D              E
# 3.0  RIL   NaN  50.0  1023  Mukesh Ambani
# 4.0  TATA  5.6   NaN  N.A.     Ratan Tata

# %%
df.iloc[5:8,...]
# Out:
#         A    B    C     D           E
# 4.0  TATA  5.6  NaN  N.A.  Ratan Tata

# %%
df.iloc[...,1:3]
# Out:
#          B        C
# NaN    Eps  Revenue
# 0.0  27.82     87.0
# 1.0   4.61      NaN
# 2.0    NaN     85.0
# 3.0    NaN     50.0
# 4.0    5.6      NaN

# %%
df
# Out:
#            A      B        C      D              E
# NaN  Tickers    Eps  Revenue  Price         People
# 0.0    GOOGL  27.82     87.0    845     Larry Page
# 1.0      WMT   4.61      NaN     65            NaN
# 2.0     MSFT    NaN     85.0     64     Bill Gates
# 3.0     RIL     NaN     50.0   1023  Mukesh Ambani
# 4.0     TATA    5.6      NaN   N.A.     Ratan Tata

# %%
df.iloc[0:15:2,...] #we use iloc in case of we find data through slicing
# Out:
#            A     B        C      D              E
# NaN  Tickers   Eps  Revenue  Price         People
# 1.0      WMT  4.61      NaN     65            NaN
# 3.0     RIL    NaN     50.0   1023  Mukesh Ambani

# %%
columns = ['A' ,'B' , 'C' , 'D','E']
num_rows =15
data = np.random.randint(1, 100,size=(num_rows,len(columns)))
df=pd.DataFrame(data,columns=columns)
df
# Out:
#      A   B   C   D   E
# 0   84  90  54  22  17
# 1   44   7  60  73  86
# 2   11  77  31  49  37
# 3   63  51  56  70  20
# 4   51  67  90   1  79
# 5    7  29  19  80  90
# 6   59  87  21  87  17
# 7   25   9  90  63  43
# 8   54  32  85  74  86
# 9   95  19  56  31  60
# 10  14   1   8  39  25
# 11  65  22  83  84   2
# 12  69  97  25  16  85
# 13  15  22  73  97  40
# 14  48  93  20  34  88

# %%
df.iloc[10:14,1:4]
# Out:
#      B   C   D
# 10   1   8  39
# 11  22  83  84
# 12  97  25  16
# 13  22  73  97

# %%
df.iloc[...,2:5]
# Out:
#      C   D   E
# 0   54  22  17
# 1   60  73  86
# 2   31  49  37
# 3   56  70  20
# 4   90   1  79
# 5   19  80  90
# 6   21  87  17
# 7   90  63  43
# 8   85  74  86
# 9   56  31  60
# 10   8  39  25
# 11  83  84   2
# 12  25  16  85
# 13  73  97  40
# 14  20  34  88

# %%
df.loc[...,["B","A","E"]] #WE USE LOC TO FIND DATA THROUGH COLUMN NAME
# Out:
#      B   A   E
# 0   90  84  17
# 1    7  44  86
# 2   77  11  37
# 3   51  63  20
# 4   67  51  79
# 5   29   7  90
# 6   87  59  17
# 7    9  25  43
# 8   32  54  86
# 9   19  95  60
# 10   1  14  25
# 11  22  65   2
# 12  97  69  85
# 13  22  15  40
# 14  93  48  88

# %%
df=pd.read_csv(r"C:\Users\lenovo\Downloads\weather_data.csv" , nrows = 2)
df
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0       day      city  \
# 0             0             0             0           0  1/1/2017  new york
# 1             1             1             1           1  1/2/2017  new york
#
#    temperature  windspeed  event
# 0           32          6   Rain
# 1           36          7  Sunny

# %%
df.to_csv("goodmorning.csv",index=False)

# %%
df.to_csv(r"C:\Users\lenovo\Downloads\weather_data.csv")

# %%
df.to_csv("goodmorning.csv",index=False,header=False)

# %%
df.to_excel("Samplesuperstore.xlsv",index=False,sheet_name="Pushparaj2")
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\OneDrive\Attachments\Lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File ~\OneDrive\Attachments\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File ~\OneDrive\Attachments\Lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\lenovo\Downloads\weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df["temperature"].max()
# Out:
# 92

# %%
df["temperature"].min()
# Out:
# 28

# %%
df["city"]
# Out:
# 0     new york
# 1     new york
# 2     new york
# 3     new york
# 4       mumbai
# 5       mumbai
# 6       mumbai
# 7       mumbai
# 8        paris
# 9        paris
# 10       paris
# 11       paris
# Name: city, dtype: object

# %%
df[df["city"]=="new york"]
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
df["city"]=="new york"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# Name: city, dtype: bool

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df[df["city"]=="paris" or df[city]=="new york"] #Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13656\2753197826.py in ?()
# ----> 1 df[df["city"]=="paris" or df[city]=="new york"] #Error
#
# ~\OneDrive\Attachments\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(df["city"]=="paris") | (df["city"]=="new york")]
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
dict = {"Name":["muskan","amitabh","aakriti"],
        "Age":[21,24,20],
         "Roll No":[1,2,3]
}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#       Name  Age  Roll No
# 0   muskan   21        1
# 1  amitabh   24        2
# 2  aakriti   20        3

# %%
df.to_csv("friends.csv")

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.049167
# 1     0.177948
# 2     0.940770
# 3     0.627718
# 4     0.211792
# 5     0.357023
# 6     0.519253
# 7     0.189331
# 8     0.409486
# 9     0.654128
# 10    0.993329
# 11    0.084839
# 12    0.359443
# 13    0.328821
# 14    0.573166
# 15    0.519938
# 16    0.048725
# 17    0.929065
# 18    0.192771
# 19    0.259756
# 20    0.367291
# 21    0.045896
# 22    0.520179
# 23    0.658207
# 24    0.934120
# 25    0.244232
# 26    0.802958
# 27    0.026309
# 28    0.561921
# 29    0.194074
# 30    0.742185
# 31    0.955185
# 32    0.912222
# 33    0.019267
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.709426  0.533121  0.973180  0.559273  0.118609
# 1    0.794280  0.301840  0.809987  0.657793  0.198400
# 2    0.286400  0.901560  0.383249  0.729334  0.844113
# 3    0.180705  0.428925  0.082203  0.627951  0.565594
# 4    0.494714  0.958747  0.820640  0.358983  0.810835
# ..        ...       ...       ...       ...       ...
# 329  0.666236  0.081898  0.229572  0.976879  0.840326
# 330  0.498145  0.373663  0.731431  0.126186  0.643697
# 331  0.605524  0.747121  0.477629  0.870544  0.078676
# 332  0.397781  0.969358  0.931414  0.456778  0.275934
# 333  0.749738  0.973861  0.954827  0.656331  0.445958
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.484254    0.514922    0.489836    0.489279    0.506122
# std      0.283034    0.293676    0.286644    0.297646    0.284245
# min      0.002173    0.000926    0.003864    0.003989    0.004014
# 25%      0.243401    0.284028    0.240346    0.236611    0.279048
# 50%      0.492104    0.520690    0.492983    0.465703    0.507444
# 75%      0.712063    0.777255    0.734054    0.752667    0.737809
# max      0.992833    0.990916    0.992216    0.998238    0.997347

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0
# %%
newdf.reset_index()
# Out:
#      index         A         B         C         D         E
# 0        0       652  0.533121  0.973180  0.559273  0.118609
# 1        1   0.79428  0.301840  0.809987  0.657793  0.198400
# 2        2    0.2864  0.901560  0.383249  0.729334  0.844113
# 3        3  0.180705  0.428925  0.082203  0.627951  0.565594
# 4        4  0.494714  0.958747  0.820640  0.358983  0.810835
# ..     ...       ...       ...       ...       ...       ...
# 329    329  0.666236  0.081898  0.229572  0.976879  0.840326
# 330    330  0.498145  0.373663  0.731431  0.126186  0.643697
# 331    331  0.605524  0.747121  0.477629  0.870544  0.078676
# 332    332  0.397781  0.969358  0.931414  0.456778  0.275934
# 333    333  0.749738  0.973861  0.954827  0.656331  0.445958
#
# [334 rows x 6 columns]

# %%
newdf.reset_index(drop=True)
# Out:
#             A         B         C         D         E
# 0         652  0.533121  0.973180  0.559273  0.118609
# 1     0.79428  0.301840  0.809987  0.657793  0.198400
# 2      0.2864  0.901560  0.383249  0.729334  0.844113
# 3    0.180705  0.428925  0.082203  0.627951  0.565594
# 4    0.494714  0.958747  0.820640  0.358983  0.810835
# ..        ...       ...       ...       ...       ...
# 329  0.666236  0.081898  0.229572  0.976879  0.840326
# 330  0.498145  0.373663  0.731431  0.126186  0.643697
# 331  0.605524  0.747121  0.477629  0.870544  0.078676
# 332  0.397781  0.969358  0.931414  0.456778  0.275934
# 333  0.749738  0.973861  0.954827  0.656331  0.445958
#
# [334 rows x 5 columns]

# %%
newdf.dropna(how = 'all',axis=1)
# Out:
#             A         B         C         D         E
# 0         652  0.533121  0.973180  0.559273  0.118609
# 1     0.79428  0.301840  0.809987  0.657793  0.198400
# 2      0.2864  0.901560  0.383249  0.729334  0.844113
# 3    0.180705  0.428925  0.082203  0.627951  0.565594
# 4    0.494714  0.958747  0.820640  0.358983  0.810835
# ..        ...       ...       ...       ...       ...
# 329  0.666236  0.081898  0.229572  0.976879  0.840326
# 330  0.498145  0.373663  0.731431  0.126186  0.643697
# 331  0.605524  0.747121  0.477629  0.870544  0.078676
# 332  0.397781  0.969358  0.931414  0.456778  0.275934
# 333  0.749738  0.973861  0.954827  0.656331  0.445958
#
# [334 rows x 5 columns]

# %%
newdf.drop_duplicates(subset = ['A'],keep = False)
# Out:
#             A         B         C         D         E
# 0         652  0.533121  0.973180  0.559273  0.118609
# 1     0.79428  0.301840  0.809987  0.657793  0.198400
# 2      0.2864  0.901560  0.383249  0.729334  0.844113
# 3    0.180705  0.428925  0.082203  0.627951  0.565594
# 4    0.494714  0.958747  0.820640  0.358983  0.810835
# ..        ...       ...       ...       ...       ...
# 329  0.666236  0.081898  0.229572  0.976879  0.840326
# 330  0.498145  0.373663  0.731431  0.126186  0.643697
# 331  0.605524  0.747121  0.477629  0.870544  0.078676
# 332  0.397781  0.969358  0.931414  0.456778  0.275934
# 333  0.749738  0.973861  0.954827  0.656331  0.445958
#
# [334 rows x 5 columns]

# %%
newdf.shape
# Out:
# (334, 5)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 333
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       334 non-null    object
#  1   B       334 non-null    float64
#  2   C       334 non-null    float64
#  3   D       334 non-null    float64
#  4   E       334 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 20.5+ KB

# %%
newdf.notnull()
# Out:
#         A     B     C     D     E
# 0    True  True  True  True  True
# 1    True  True  True  True  True
# 2    True  True  True  True  True
# 3    True  True  True  True  True
# 4    True  True  True  True  True
# ..    ...   ...   ...   ...   ...
# 329  True  True  True  True  True
# 330  True  True  True  True  True
# 331  True  True  True  True  True
# 332  True  True  True  True  True
# 333  True  True  True  True  True
#
# [334 rows x 5 columns]
